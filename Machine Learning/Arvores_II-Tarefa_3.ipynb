# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Árvores II - Tarefa 3

# %% [markdown]
# ### 1. Carregar as bases
#
# Vamos utilizar nesta tarefa as bases de reconhecimento de atividade humana através do celular. Carregue novamente as bases salvas na tarefa I.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
import statsmodels.api as sm

# %%
features = pd.read_csv(r".\UCI HAR Dataset\features.txt", delim_whitespace=True, header=None)
subject = pd.read_csv(r".\UCI HAR Dataset\train\subject_train.txt",delim_whitespace=True,header=None)
subject_test = pd.read_csv(r".\UCI HAR Dataset\test\subject_test.txt",delim_whitespace=True,header=None)

X_train = pd.read_csv(r".\UCI HAR Dataset\train\X_train.txt",delim_whitespace=True,header=None)
y_train = pd.read_csv(r".\UCI HAR Dataset\train\y_train.txt",delim_whitespace=True,header=None)

X_test = pd.read_csv(r".\UCI HAR Dataset\test\X_test.txt",delim_whitespace=True,header=None)
y_test = pd.read_csv(r".\UCI HAR Dataset\test\y_test.txt",delim_whitespace=True,header=None)

X_train.columns = features.values[:,1] ## obtendo apenas os valores da série (sem o índice)
X_test.columns = features.values[:,1] ## obtendo apenas os valores da série (sem o índice)


X_train['individuo'] = subject
X_test['individuo'] = subject_test

X_train.set_index([X_train.index, 'individuo'], drop=True)
X_test.set_index([X_test.index, 'individuo'], drop=True)
# Out:
#                 tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
#      individuo
# 0    2                   0.257178          -0.023285          -0.014654
# 1    2                   0.286027          -0.013163          -0.119083
# 2    2                   0.275485          -0.026050          -0.118152
# 3    2                   0.270298          -0.032614          -0.117520
# 4    2                   0.274833          -0.027848          -0.129527
# ...                           ...                ...                ...
# 2942 24                  0.310155          -0.053391          -0.099109
# 2943 24                  0.363385          -0.039214          -0.105915
# 2944 24                  0.349966           0.030077          -0.115788
# 2945 24                  0.237594           0.018467          -0.096499
# 2946 24                  0.153627          -0.018437          -0.137018
#
#                 tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  \
#      individuo
# 0    2                 -0.938404         -0.920091         -0.667683
# 1    2                 -0.975415         -0.967458         -0.944958
# 2    2                 -0.993819         -0.969926         -0.962748
# 3    2                 -0.994743         -0.973268         -0.967091
# 4    2                 -0.993852         -0.967445         -0.978295
# ...                          ...               ...               ...
# 2942 24                -0.287866         -0.140589         -0.215088
# 2943 24                -0.305388          0.028148         -0.196373
# 2944 24                -0.329638         -0.042143         -0.250181
# 2945 24                -0.323114         -0.229775         -0.207574
# 2946 24                -0.330046         -0.195253         -0.164339
#
#                 tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  \
#      individuo
# 0    2                 -0.952501         -0.925249         -0.674302
# 1    2                 -0.986799         -0.968401         -0.945823
# 2    2                 -0.994403         -0.970735         -0.963483
# 3    2                 -0.995274         -0.974471         -0.968897
# 4    2                 -0.994111         -0.965953         -0.977346
# ...                          ...               ...               ...
# 2942 24                -0.356083         -0.148775         -0.232057
# 2943 24                -0.373540         -0.030036         -0.270237
# 2944 24                -0.388017         -0.133257         -0.347029
# 2945 24                -0.392380         -0.279610         -0.289477
# 2946 24                -0.430974         -0.218295         -0.229933
#
#                 tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-meanFreq()  \
#      individuo                    ...
# 0    2                 -0.894088  ...                         0.071645
# 1    2                 -0.894088  ...                        -0.401189
# 2    2                 -0.939260  ...                         0.062891
# 3    2                 -0.938610  ...                         0.116695
# 4    2                 -0.938610  ...                        -0.121711
# ...                          ...  ...                              ...
# 2942 24                 0.185361  ...                         0.074472
# 2943 24                 0.185361  ...                         0.101859
# 2944 24                 0.007471  ...                        -0.066249
# 2945 24                 0.007471  ...                        -0.046467
# 2946 24                -0.111527  ...                        -0.010386
#
#                 fBodyBodyGyroJerkMag-skewness()  \
#      individuo
# 0    2                                -0.330370
# 1    2                                -0.121845
# 2    2                                -0.190422
# 3    2                                -0.344418
# 4    2                                -0.534685
# ...                                         ...
# 2942 24                               -0.376278
# 2943 24                               -0.320418
# 2944 24                               -0.118854
# 2945 24                               -0.205445
# 2946 24                               -0.072237
#
#                 fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
#      individuo
# 0    2                                -0.705974                     0.006462
# 1    2                                -0.594944                    -0.083495
# 2    2                                -0.640736                    -0.034956
# 3    2                                -0.736124                    -0.017067
# 4    2                                -0.846595                    -0.002223
# ...                                         ...                          ...
# 2942 24                               -0.750809                    -0.337422
# 2943 24                               -0.700274                    -0.736701
# 2944 24                               -0.467179                    -0.181560
# 2945 24                               -0.617737                     0.444558
# 2946 24                               -0.436940                     0.598808
#
#                 angle(tBodyAccJerkMean),gravityMean)  \
#      individuo
# 0    2                                      0.162920
# 1    2                                      0.017500
# 2    2                                      0.202302
# 3    2                                      0.154438
# 4    2                                     -0.040046
# ...                                              ...
# 2942 24                                     0.346295
# 2943 24                                    -0.372889
# 2944 24                                     0.088574
# 2945 24                                    -0.819188
# 2946 24                                    -0.287951
#
#                 angle(tBodyGyroMean,gravityMean)  \
#      individuo
# 0    2                                 -0.825886
# 1    2                                 -0.434375
# 2    2                                  0.064103
# 3    2                                  0.340134
# 4    2                                  0.736715
# ...                                          ...
# 2942 24                                 0.884904
# 2943 24                                -0.657421
# 2944 24                                 0.696663
# 2945 24                                 0.929294
# 2946 24                                 0.876030
#
#                 angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
#      individuo
# 0    2                                      0.271151             -0.720009
# 1    2                                      0.920593             -0.698091
# 2    2                                      0.145068             -0.702771
# 3    2                                      0.296407             -0.698954
# 4    2                                     -0.118545             -0.692245
# ...                                              ...                   ...
# 2942 24                                    -0.698885             -0.651732
# 2943 24                                     0.322549             -0.655181
# 2944 24                                     0.363139             -0.655357
# 2945 24                                    -0.008398             -0.659719
# 2946 24                                    -0.024965             -0.660080
#
#                 angle(Y,gravityMean)  angle(Z,gravityMean)
#      individuo
# 0    2                      0.276801             -0.057978
# 1    2                      0.281343             -0.083898
# 2    2                      0.280083             -0.079346
# 3    2                      0.284114             -0.077108
# 4    2                      0.290722             -0.073857
# ...                              ...                   ...
# 2942 24                     0.274627              0.184784
# 2943 24                     0.273578              0.182412
# 2944 24                     0.274479              0.181184
# 2945 24                     0.264782              0.187563
# 2946 24                     0.263936              0.188103
#
# [2947 rows x 561 columns]

# %% [markdown]
# ### 2. Calcule os ```ccp_alphas```.
#
# Vamos seguir uma lógica bem em linha com o que já estamso acostumados, com as seguintes orientações:
#
# - Utilizar treinamento e teste conforme já vieram definidos originalmente
# - Por pragmatismo, utilizar ```min_samples_leaf=20```
# - Utilize as mesmas "3 melhores variáveis" identificadas no exercício anterior.

# %%
top_test = X_test[['tGravityAcc-min()-X','fBodyAcc-mad()-X','angle(Y,gravityMean)']]
top_train = X_train[['tGravityAcc-min()-X','fBodyAcc-mad()-X','angle(Y,gravityMean)']]

# %%
# %%time
clf = DecisionTreeClassifier(random_state=42, min_samples_leaf=20).fit(top_train, y_train)
path = clf.cost_complexity_pruning_path(top_test, y_test)
ccp_alphas, impurities = path.ccp_alphas, path.impurities
# Out:
# CPU times: total: 46.9 ms
# Wall time: 26.8 ms

# %% [markdown]
# ### 3. *Grid Search*
#
# Vou deixar especificações iniciais mínimas, que visam limitar o tempo de máquina, pois um procedimento desses pode demorar muito tempo dependendo da especificação. Mas conforme você for ficando confortável com o tempo consumido pelo procedimento, pode fazer um algoritmo mais exaustivo, por exemplo, avaliando mais valores de ```ccp_alpha```.
#
# - Meça o tempo
# - Utilize a base de treinamento
# - Utilize um *cross validation* do tipo *k-fold*, especifique k=10
# - Você pode ler 1 a cada ```k``` valores para uma melhor varredura utilizando, por exemplo, ```ccp_alpha[::10]```
# - Não se esqueça de limitar o número de variáveis

# %%
grid_parametros = {'ccp_alpha':ccp_alphas}

# %%
# %%time

grid = GridSearchCV(estimator = clf, param_grid=grid_parametros,cv=10, verbose=100)
grid.fit(top_train, y_train)
# Out:
# Fitting 10 folds for each of 53 candidates, totalling 530 fits
# [CV 1/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 1/10; 1/53] END ..............ccp_alpha=0.0;, score=0.719 total time=   0.0s
# [CV 2/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 2/10; 1/53] END ..............ccp_alpha=0.0;, score=0.736 total time=   0.0s
# [CV 3/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 3/10; 1/53] END ..............ccp_alpha=0.0;, score=0.833 total time=   0.0s
# [CV 4/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 4/10; 1/53] END ..............ccp_alpha=0.0;, score=0.727 total time=   0.0s
# [CV 5/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 5/10; 1/53] END ..............ccp_alpha=0.0;, score=0.771 total time=   0.0s
# [CV 6/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 6/10; 1/53] END ..............ccp_alpha=0.0;, score=0.770 total time=   0.0s
# [CV 7/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 7/10; 1/53] END ..............ccp_alpha=0.0;, score=0.780 total time=   0.0s
# [CV 8/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 8/10; 1/53] END ..............ccp_alpha=0.0;, score=0.736 total time=   0.0s
# [CV 9/10; 1/53] START ccp_alpha=0.0.............................................
# [CV 9/10; 1/53] END ..............ccp_alpha=0.0;, score=0.846 total time=   0.0s
# [CV 10/10; 1/53] START ccp_alpha=0.0............................................
# [CV 10/10; 1/53] END .............ccp_alpha=0.0;, score=0.784 total time=   0.0s
# [CV 1/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 1/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.719 total time=   0.0s
# [CV 2/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 2/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.736 total time=   0.0s
# [CV 3/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 3/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.833 total time=   0.0s
# [CV 4/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 4/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.727 total time=   0.0s
# [CV 5/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 5/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.771 total time=   0.0s
# [CV 6/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 6/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.770 total time=   0.0s
# [CV 7/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 7/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.780 total time=   0.0s
# [CV 8/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 8/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.736 total time=   0.0s
# [CV 9/10; 2/53] START ccp_alpha=1.5847410006972966e-05..........................
# [CV 9/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.846 total time=   0.0s
# [CV 10/10; 2/53] START ccp_alpha=1.5847410006972966e-05.........................
# [CV 10/10; 2/53] END ccp_alpha=1.5847410006972966e-05;, score=0.784 total time=   0.0s
# [CV 1/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 1/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.719 total time=   0.0s
# [CV 2/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 2/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.736 total time=   0.0s
# [CV 3/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 3/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.833 total time=   0.0s
# [CV 4/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 4/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.727 total time=   0.0s
# [CV 5/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 5/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.771 total time=   0.0s
# [CV 6/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 6/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.770 total time=   0.0s
# [CV 7/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 7/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.780 total time=   0.0s
# [CV 8/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 8/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.736 total time=   0.0s
# [CV 9/10; 3/53] START ccp_alpha=1.815010929522411e-05...........................
# [CV 9/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.846 total time=   0.0s
# [CV 10/10; 3/53] START ccp_alpha=1.815010929522411e-05..........................
# [CV 10/10; 3/53] END ccp_alpha=1.815010929522411e-05;, score=0.784 total time=   0.0s
# [CV 1/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 1/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.719 total time=   0.0s
# [CV 2/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 2/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.736 total time=   0.0s
# [CV 3/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 3/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.833 total time=   0.0s
# [CV 4/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 4/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.727 total time=   0.0s
# [CV 5/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 5/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.771 total time=   0.0s
# [CV 6/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 6/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.770 total time=   0.0s
# [CV 7/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 7/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.780 total time=   0.0s
# [CV 8/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 8/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.736 total time=   0.0s
# [CV 9/10; 4/53] START ccp_alpha=2.0625827528161908e-05..........................
# [CV 9/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.846 total time=   0.0s
# [CV 10/10; 4/53] START ccp_alpha=2.0625827528161908e-05.........................
# [CV 10/10; 4/53] END ccp_alpha=2.0625827528161908e-05;, score=0.784 total time=   0.0s
# [CV 1/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 1/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.719 total time=   0.0s
# [CV 2/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 2/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.736 total time=   0.0s
# [CV 3/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 3/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.833 total time=   0.0s
# [CV 4/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 4/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.727 total time=   0.0s
# [CV 5/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 5/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.771 total time=   0.0s
# [CV 6/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 6/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.770 total time=   0.0s
# [CV 7/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 7/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.780 total time=   0.0s
# [CV 8/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 8/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.736 total time=   0.0s
# [CV 9/10; 5/53] START ccp_alpha=3.197137875099194e-05...........................
# [CV 9/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.846 total time=   0.0s
# [CV 10/10; 5/53] START ccp_alpha=3.197137875099194e-05..........................
# [CV 10/10; 5/53] END ccp_alpha=3.197137875099194e-05;, score=0.784 total time=   0.0s
# [CV 1/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 1/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.719 total time=   0.0s
# [CV 2/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 2/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.736 total time=   0.0s
# [CV 3/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 3/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.833 total time=   0.0s
# [CV 4/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 4/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.732 total time=   0.0s
# [CV 5/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 5/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.771 total time=   0.0s
# [CV 6/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 6/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.770 total time=   0.0s
# [CV 7/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 7/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.780 total time=   0.0s
# [CV 8/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 8/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.736 total time=   0.0s
# [CV 9/10; 6/53] START ccp_alpha=8.965138046374953e-05...........................
# [CV 9/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.846 total time=   0.0s
# [CV 10/10; 6/53] START ccp_alpha=8.965138046374953e-05..........................
# [CV 10/10; 6/53] END ccp_alpha=8.965138046374953e-05;, score=0.784 total time=   0.0s
# [CV 1/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 1/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.719 total time=   0.0s
# [CV 2/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 2/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.736 total time=   0.0s
# [CV 3/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 3/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.833 total time=   0.0s
# [CV 4/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 4/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.732 total time=   0.0s
# [CV 5/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 5/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.771 total time=   0.0s
# [CV 6/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 6/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.770 total time=   0.0s
# [CV 7/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 7/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.780 total time=   0.0s
# [CV 8/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 8/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.736 total time=   0.0s
# [CV 9/10; 7/53] START ccp_alpha=0.00012136815665828244..........................
# [CV 9/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.846 total time=   0.0s
# [CV 10/10; 7/53] START ccp_alpha=0.00012136815665828244.........................
# [CV 10/10; 7/53] END ccp_alpha=0.00012136815665828244;, score=0.784 total time=   0.0s
# [CV 1/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 1/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.719 total time=   0.0s
# [CV 2/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 2/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.736 total time=   0.0s
# [CV 3/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 3/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.833 total time=   0.0s
# [CV 4/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 4/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.732 total time=   0.0s
# [CV 5/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 5/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.771 total time=   0.0s
# [CV 6/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 6/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.770 total time=   0.0s
# [CV 7/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 7/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.780 total time=   0.0s
# [CV 8/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 8/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.736 total time=   0.0s
# [CV 9/10; 8/53] START ccp_alpha=0.00015265328268163373..........................
# [CV 9/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.846 total time=   0.0s
# [CV 10/10; 8/53] START ccp_alpha=0.00015265328268163373.........................
# [CV 10/10; 8/53] END ccp_alpha=0.00015265328268163373;, score=0.784 total time=   0.0s
# [CV 1/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 1/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.719 total time=   0.0s
# [CV 2/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 2/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.736 total time=   0.0s
# [CV 3/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 3/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.833 total time=   0.0s
# [CV 4/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 4/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.732 total time=   0.0s
# [CV 5/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 5/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.771 total time=   0.0s
# [CV 6/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 6/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.770 total time=   0.0s
# [CV 7/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 7/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.780 total time=   0.0s
# [CV 8/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 8/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.736 total time=   0.0s
# [CV 9/10; 9/53] START ccp_alpha=0.00015971824064214737..........................
# [CV 9/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.846 total time=   0.0s
# [CV 10/10; 9/53] START ccp_alpha=0.00015971824064214737.........................
# [CV 10/10; 9/53] END ccp_alpha=0.00015971824064214737;, score=0.784 total time=   0.0s
# [CV 1/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 1/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.727 total time=   0.0s
# [CV 2/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 2/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.736 total time=   0.0s
# [CV 3/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 3/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.833 total time=   0.0s
# [CV 4/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 4/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.732 total time=   0.0s
# [CV 5/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 5/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.771 total time=   0.0s
# [CV 6/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 6/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.770 total time=   0.0s
# [CV 7/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 7/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.780 total time=   0.0s
# [CV 8/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 8/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.737 total time=   0.0s
# [CV 9/10; 10/53] START ccp_alpha=0.0002705947971531424..........................
# [CV 9/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.846 total time=   0.0s
# [CV 10/10; 10/53] START ccp_alpha=0.0002705947971531424.........................
# [CV 10/10; 10/53] END ccp_alpha=0.0002705947971531424;, score=0.784 total time=   0.0s
# [CV 1/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 1/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.727 total time=   0.0s
# [CV 2/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 2/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.736 total time=   0.0s
# [CV 3/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 3/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.833 total time=   0.0s
# [CV 4/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 4/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.732 total time=   0.0s
# [CV 5/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 5/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.771 total time=   0.0s
# [CV 6/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 6/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.770 total time=   0.0s
# [CV 7/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 7/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.780 total time=   0.0s
# [CV 8/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 8/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.737 total time=   0.0s
# [CV 9/10; 11/53] START ccp_alpha=0.0002714625042416021..........................
# [CV 9/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.846 total time=   0.0s
# [CV 10/10; 11/53] START ccp_alpha=0.0002714625042416021.........................
# [CV 10/10; 11/53] END ccp_alpha=0.0002714625042416021;, score=0.784 total time=   0.0s
# [CV 1/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 1/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.727 total time=   0.0s
# [CV 2/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 2/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.735 total time=   0.0s
# [CV 3/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 3/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.833 total time=   0.0s
# [CV 4/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 4/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.732 total time=   0.0s
# [CV 5/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 5/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.771 total time=   0.0s
# [CV 6/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 6/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.770 total time=   0.0s
# [CV 7/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 7/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.780 total time=   0.0s
# [CV 8/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 8/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.737 total time=   0.0s
# [CV 9/10; 12/53] START ccp_alpha=0.0002858186943697676..........................
# [CV 9/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.846 total time=   0.0s
# [CV 10/10; 12/53] START ccp_alpha=0.0002858186943697676.........................
# [CV 10/10; 12/53] END ccp_alpha=0.0002858186943697676;, score=0.784 total time=   0.0s
# [CV 1/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 1/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.727 total time=   0.0s
# [CV 2/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 2/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.735 total time=   0.0s
# [CV 3/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 3/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.829 total time=   0.0s
# [CV 4/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 4/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.732 total time=   0.0s
# [CV 5/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 5/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.771 total time=   0.0s
# [CV 6/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 6/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.769 total time=   0.0s
# [CV 7/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 7/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.780 total time=   0.0s
# [CV 8/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 8/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.737 total time=   0.0s
# [CV 9/10; 13/53] START ccp_alpha=0.0003404668422127381..........................
# [CV 9/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.846 total time=   0.0s
# [CV 10/10; 13/53] START ccp_alpha=0.0003404668422127381.........................
# [CV 10/10; 13/53] END ccp_alpha=0.0003404668422127381;, score=0.784 total time=   0.0s
# [CV 1/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 1/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.727 total time=   0.0s
# [CV 2/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 2/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.735 total time=   0.0s
# [CV 3/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 3/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.829 total time=   0.0s
# [CV 4/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 4/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.732 total time=   0.0s
# [CV 5/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 5/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.771 total time=   0.0s
# [CV 6/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 6/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.769 total time=   0.0s
# [CV 7/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 7/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.780 total time=   0.0s
# [CV 8/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 8/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.737 total time=   0.0s
# [CV 9/10; 14/53] START ccp_alpha=0.0003419343371399578..........................
# [CV 9/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.846 total time=   0.0s
# [CV 10/10; 14/53] START ccp_alpha=0.0003419343371399578.........................
# [CV 10/10; 14/53] END ccp_alpha=0.0003419343371399578;, score=0.784 total time=   0.0s
# [CV 1/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 1/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.727 total time=   0.0s
# [CV 2/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 2/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.735 total time=   0.0s
# [CV 3/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 3/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.824 total time=   0.0s
# [CV 4/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 4/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.731 total time=   0.0s
# [CV 5/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 5/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.780 total time=   0.0s
# [CV 6/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 6/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.769 total time=   0.0s
# [CV 7/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 7/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.756 total time=   0.0s
# [CV 8/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 8/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.710 total time=   0.0s
# [CV 9/10; 15/53] START ccp_alpha=0.000608219966889801...........................
# [CV 9/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.846 total time=   0.0s
# [CV 10/10; 15/53] START ccp_alpha=0.000608219966889801..........................
# [CV 10/10; 15/53] END ccp_alpha=0.000608219966889801;, score=0.778 total time=   0.0s
# [CV 1/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 1/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.727 total time=   0.0s
# [CV 2/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 2/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.735 total time=   0.0s
# [CV 3/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 3/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.824 total time=   0.0s
# [CV 4/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 4/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.731 total time=   0.0s
# [CV 5/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 5/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.780 total time=   0.0s
# [CV 6/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 6/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.769 total time=   0.0s
# [CV 7/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 7/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.756 total time=   0.0s
# [CV 8/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 8/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.710 total time=   0.0s
# [CV 9/10; 16/53] START ccp_alpha=0.0006085077982376482..........................
# [CV 9/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.846 total time=   0.0s
# [CV 10/10; 16/53] START ccp_alpha=0.0006085077982376482.........................
# [CV 10/10; 16/53] END ccp_alpha=0.0006085077982376482;, score=0.778 total time=   0.0s
# [CV 1/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 1/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.720 total time=   0.0s
# [CV 2/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 2/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.734 total time=   0.0s
# [CV 3/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 3/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.839 total time=   0.0s
# [CV 4/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 4/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.748 total time=   0.0s
# [CV 5/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 5/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.797 total time=   0.0s
# [CV 6/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 6/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.766 total time=   0.0s
# [CV 7/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 7/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.756 total time=   0.0s
# [CV 8/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 8/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.710 total time=   0.0s
# [CV 9/10; 17/53] START ccp_alpha=0.0007095202145746241..........................
# [CV 9/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.846 total time=   0.0s
# [CV 10/10; 17/53] START ccp_alpha=0.0007095202145746241.........................
# [CV 10/10; 17/53] END ccp_alpha=0.0007095202145746241;, score=0.778 total time=   0.0s
# [CV 1/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 1/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.720 total time=   0.0s
# [CV 2/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 2/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.734 total time=   0.0s
# [CV 3/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 3/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.839 total time=   0.0s
# [CV 4/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 4/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.748 total time=   0.0s
# [CV 5/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 5/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.797 total time=   0.0s
# [CV 6/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 6/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.766 total time=   0.0s
# [CV 7/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 7/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.756 total time=   0.0s
# [CV 8/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 8/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.710 total time=   0.0s
# [CV 9/10; 18/53] START ccp_alpha=0.0007251748495999766..........................
# [CV 9/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.846 total time=   0.0s
# [CV 10/10; 18/53] START ccp_alpha=0.0007251748495999766.........................
# [CV 10/10; 18/53] END ccp_alpha=0.0007251748495999766;, score=0.800 total time=   0.0s
# [CV 1/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 1/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.720 total time=   0.0s
# [CV 2/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 2/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.734 total time=   0.0s
# [CV 3/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 3/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.839 total time=   0.0s
# [CV 4/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 4/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.748 total time=   0.0s
# [CV 5/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 5/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.797 total time=   0.0s
# [CV 6/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 6/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.766 total time=   0.0s
# [CV 7/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 7/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.756 total time=   0.0s
# [CV 8/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 8/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.710 total time=   0.0s
# [CV 9/10; 19/53] START ccp_alpha=0.0007285740733514153..........................
# [CV 9/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.846 total time=   0.0s
# [CV 10/10; 19/53] START ccp_alpha=0.0007285740733514153.........................
# [CV 10/10; 19/53] END ccp_alpha=0.0007285740733514153;, score=0.800 total time=   0.0s
# [CV 1/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 1/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.723 total time=   0.0s
# [CV 2/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 2/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.734 total time=   0.0s
# [CV 3/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 3/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.848 total time=   0.0s
# [CV 4/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 4/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.747 total time=   0.0s
# [CV 5/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 5/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.797 total time=   0.0s
# [CV 6/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 6/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.761 total time=   0.0s
# [CV 7/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 7/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.758 total time=   0.0s
# [CV 8/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 8/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.710 total time=   0.0s
# [CV 9/10; 20/53] START ccp_alpha=0.0008165419770441839..........................
# [CV 9/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.844 total time=   0.0s
# [CV 10/10; 20/53] START ccp_alpha=0.0008165419770441839.........................
# [CV 10/10; 20/53] END ccp_alpha=0.0008165419770441839;, score=0.800 total time=   0.0s
# [CV 1/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 1/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.723 total time=   0.0s
# [CV 2/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 2/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.734 total time=   0.0s
# [CV 3/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 3/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.850 total time=   0.0s
# [CV 4/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 4/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.747 total time=   0.0s
# [CV 5/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 5/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.797 total time=   0.0s
# [CV 6/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 6/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.761 total time=   0.0s
# [CV 7/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 7/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.758 total time=   0.0s
# [CV 8/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 8/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.713 total time=   0.0s
# [CV 9/10; 21/53] START ccp_alpha=0.0008453787815913983..........................
# [CV 9/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.844 total time=   0.0s
# [CV 10/10; 21/53] START ccp_alpha=0.0008453787815913983.........................
# [CV 10/10; 21/53] END ccp_alpha=0.0008453787815913983;, score=0.800 total time=   0.0s
# [CV 1/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 1/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.734 total time=   0.0s
# [CV 2/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 2/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.736 total time=   0.0s
# [CV 3/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 3/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.850 total time=   0.0s
# [CV 4/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 4/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.769 total time=   0.0s
# [CV 5/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 5/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.797 total time=   0.0s
# [CV 6/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 6/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.762 total time=   0.0s
# [CV 7/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 7/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.790 total time=   0.0s
# [CV 8/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 8/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.713 total time=   0.0s
# [CV 9/10; 22/53] START ccp_alpha=0.0008929625357485295..........................
# [CV 9/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.849 total time=   0.0s
# [CV 10/10; 22/53] START ccp_alpha=0.0008929625357485295.........................
# [CV 10/10; 22/53] END ccp_alpha=0.0008929625357485295;, score=0.800 total time=   0.0s
# [CV 1/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 1/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.734 total time=   0.0s
# [CV 2/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 2/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.736 total time=   0.0s
# [CV 3/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 3/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.850 total time=   0.0s
# [CV 4/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 4/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.769 total time=   0.0s
# [CV 5/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 5/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.797 total time=   0.0s
# [CV 6/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 6/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.785 total time=   0.0s
# [CV 7/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 7/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.811 total time=   0.0s
# [CV 8/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 8/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.697 total time=   0.0s
# [CV 9/10; 23/53] START ccp_alpha=0.0009442174060577437..........................
# [CV 9/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.867 total time=   0.0s
# [CV 10/10; 23/53] START ccp_alpha=0.0009442174060577437.........................
# [CV 10/10; 23/53] END ccp_alpha=0.0009442174060577437;, score=0.800 total time=   0.0s
# [CV 1/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 1/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.774 total time=   0.0s
# [CV 2/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 2/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.736 total time=   0.0s
# [CV 3/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 3/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.850 total time=   0.0s
# [CV 4/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 4/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.777 total time=   0.0s
# [CV 5/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 5/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.762 total time=   0.0s
# [CV 6/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 6/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.785 total time=   0.0s
# [CV 7/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 7/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.811 total time=   0.0s
# [CV 8/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 8/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.697 total time=   0.0s
# [CV 9/10; 24/53] START ccp_alpha=0.0010591874676580196..........................
# [CV 9/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.867 total time=   0.0s
# [CV 10/10; 24/53] START ccp_alpha=0.0010591874676580196.........................
# [CV 10/10; 24/53] END ccp_alpha=0.0010591874676580196;, score=0.800 total time=   0.0s
# [CV 1/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 1/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.777 total time=   0.0s
# [CV 2/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 2/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.736 total time=   0.0s
# [CV 3/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 3/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.864 total time=   0.0s
# [CV 4/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 4/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.790 total time=   0.0s
# [CV 5/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 5/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.741 total time=   0.0s
# [CV 6/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 6/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.785 total time=   0.0s
# [CV 7/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 7/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.811 total time=   0.0s
# [CV 8/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 8/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.697 total time=   0.0s
# [CV 9/10; 25/53] START ccp_alpha=0.0011584900566828414..........................
# [CV 9/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.850 total time=   0.0s
# [CV 10/10; 25/53] START ccp_alpha=0.0011584900566828414.........................
# [CV 10/10; 25/53] END ccp_alpha=0.0011584900566828414;, score=0.800 total time=   0.0s
# [CV 1/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 1/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.830 total time=   0.0s
# [CV 2/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 2/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.793 total time=   0.0s
# [CV 3/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 3/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.833 total time=   0.0s
# [CV 4/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 4/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.769 total time=   0.0s
# [CV 5/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 5/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.777 total time=   0.0s
# [CV 6/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 6/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.793 total time=   0.0s
# [CV 7/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 7/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.800 total time=   0.0s
# [CV 8/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 8/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.725 total time=   0.0s
# [CV 9/10; 26/53] START ccp_alpha=0.0015073641639747615..........................
# [CV 9/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.849 total time=   0.0s
# [CV 10/10; 26/53] START ccp_alpha=0.0015073641639747615.........................
# [CV 10/10; 26/53] END ccp_alpha=0.0015073641639747615;, score=0.797 total time=   0.0s
# [CV 1/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 1/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.830 total time=   0.0s
# [CV 2/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 2/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.793 total time=   0.0s
# [CV 3/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 3/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.833 total time=   0.0s
# [CV 4/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 4/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.769 total time=   0.0s
# [CV 5/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 5/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.777 total time=   0.0s
# [CV 6/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 6/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.793 total time=   0.0s
# [CV 7/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 7/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.800 total time=   0.0s
# [CV 8/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 8/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.725 total time=   0.0s
# [CV 9/10; 27/53] START ccp_alpha=0.0015545559062067407..........................
# [CV 9/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.849 total time=   0.0s
# [CV 10/10; 27/53] START ccp_alpha=0.0015545559062067407.........................
# [CV 10/10; 27/53] END ccp_alpha=0.0015545559062067407;, score=0.797 total time=   0.0s
# [CV 1/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 1/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.830 total time=   0.0s
# [CV 2/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 2/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.793 total time=   0.0s
# [CV 3/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 3/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.833 total time=   0.0s
# [CV 4/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 4/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.769 total time=   0.0s
# [CV 5/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 5/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.777 total time=   0.0s
# [CV 6/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 6/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.793 total time=   0.0s
# [CV 7/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 7/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.800 total time=   0.0s
# [CV 8/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 8/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.725 total time=   0.0s
# [CV 9/10; 28/53] START ccp_alpha=0.0015700892908369918..........................
# [CV 9/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.849 total time=   0.0s
# [CV 10/10; 28/53] START ccp_alpha=0.0015700892908369918.........................
# [CV 10/10; 28/53] END ccp_alpha=0.0015700892908369918;, score=0.797 total time=   0.0s
# [CV 1/10; 29/53] START ccp_alpha=0.001613441657048931...........................
# [CV 1/10; 29/53] END ccp_alpha=0.001613441657048931;, score=0.830 total time=   0.0s
# [CV 2/10; 29/53] START ccp_alpha=0.001613441657048931...........................
# [CV 2/10; 29/53] END ccp_alpha=0.001613441657048931;, score=0.793 total time=   0.0s
# [CV 3/10; 29/53] START ccp_alpha=0.001613441657048931...........................
# [CV 3/10; 29/53] END ccp_alpha=0.001613441657048931;, score=0.833 total time=   0.0s
# [CV 4/10; 29/53] START ccp_alpha=0.001613441657048931...........................
# [CV 4/10; 29/53] END ccp_alpha=0.001613441657048931;, score=0.773 total time=   0.0s
# [CV 5/10; 29/53] START ccp_alpha=0.001613441657048931...........................
# [CV 5/10; 29/53] END ccp_alpha=0.001613441657048931;, score=0.777 total time=   0.0s
# [CV 6/10; 29/53] START ccp_alpha=0.001613441657048931...........................
# [CV 6/10; 29/53] END ccp_alpha=0.001613441657048931;, score=0.793 total time=   0.0s
# [CV 7/10; 29/53] START ccp_alpha=0.001613441657048931...........................
# [CV 7/10; 29/53] END ccp_alpha=0.001613441657048931;, score=0.805 total time=   0.0s
# ...
# [CV 10/10; 44/53] END ccp_alpha=0.011877864108037928;, score=0.733 total time=   0.0s
# [CV 1/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 1/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.829 total time=   0.0s
# [CV 2/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 2/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.818 total time=   0.0s
# [CV 3/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 3/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.871 total time=   0.0s
# [CV 4/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 4/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.781 total time=   0.0s
# [CV 5/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 5/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.818 total time=   0.0s
# [CV 6/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 6/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.800 total time=   0.0s
# [CV 7/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 7/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.824 total time=   0.0s
# [CV 8/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 8/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.784 total time=   0.0s
# [CV 9/10; 45/53] START ccp_alpha=0.01256489818252654............................
# [CV 9/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.871 total time=   0.0s
# [CV 10/10; 45/53] START ccp_alpha=0.01256489818252654...........................
# [CV 10/10; 45/53] END ccp_alpha=0.01256489818252654;, score=0.733 total time=   0.0s
# [CV 1/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 1/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.829 total time=   0.0s
# [CV 2/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 2/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.818 total time=   0.0s
# [CV 3/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 3/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.871 total time=   0.0s
# [CV 4/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 4/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.781 total time=   0.0s
# [CV 5/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 5/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.818 total time=   0.0s
# [CV 6/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 6/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.800 total time=   0.0s
# [CV 7/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 7/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.824 total time=   0.0s
# [CV 8/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 8/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.784 total time=   0.0s
# [CV 9/10; 46/53] START ccp_alpha=0.015066521311202112...........................
# [CV 9/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.871 total time=   0.0s
# [CV 10/10; 46/53] START ccp_alpha=0.015066521311202112..........................
# [CV 10/10; 46/53] END ccp_alpha=0.015066521311202112;, score=0.733 total time=   0.0s
# [CV 1/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 1/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.829 total time=   0.0s
# [CV 2/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 2/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.818 total time=   0.0s
# [CV 3/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 3/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.871 total time=   0.0s
# [CV 4/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 4/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.781 total time=   0.0s
# [CV 5/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 5/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.818 total time=   0.0s
# [CV 6/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 6/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.833 total time=   0.0s
# [CV 7/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 7/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.824 total time=   0.0s
# [CV 8/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 8/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.784 total time=   0.0s
# [CV 9/10; 47/53] START ccp_alpha=0.01608191630591157............................
# [CV 9/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.871 total time=   0.0s
# [CV 10/10; 47/53] START ccp_alpha=0.01608191630591157...........................
# [CV 10/10; 47/53] END ccp_alpha=0.01608191630591157;, score=0.733 total time=   0.0s
# [CV 1/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 1/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.829 total time=   0.0s
# [CV 2/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 2/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.818 total time=   0.0s
# [CV 3/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 3/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.871 total time=   0.0s
# [CV 4/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 4/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.781 total time=   0.0s
# [CV 5/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 5/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.818 total time=   0.0s
# [CV 6/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 6/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.833 total time=   0.0s
# [CV 7/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 7/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.824 total time=   0.0s
# [CV 8/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 8/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.784 total time=   0.0s
# [CV 9/10; 48/53] START ccp_alpha=0.018986633882814352...........................
# [CV 9/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.871 total time=   0.0s
# [CV 10/10; 48/53] START ccp_alpha=0.018986633882814352..........................
# [CV 10/10; 48/53] END ccp_alpha=0.018986633882814352;, score=0.733 total time=   0.0s
# [CV 1/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 1/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.829 total time=   0.0s
# [CV 2/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 2/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.818 total time=   0.0s
# [CV 3/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 3/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.871 total time=   0.0s
# [CV 4/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 4/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.781 total time=   0.0s
# [CV 5/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 5/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.818 total time=   0.0s
# [CV 6/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 6/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.833 total time=   0.0s
# [CV 7/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 7/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.824 total time=   0.0s
# [CV 8/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 8/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.784 total time=   0.0s
# [CV 9/10; 49/53] START ccp_alpha=0.03552522624122184............................
# [CV 9/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.871 total time=   0.0s
# [CV 10/10; 49/53] START ccp_alpha=0.03552522624122184...........................
# [CV 10/10; 49/53] END ccp_alpha=0.03552522624122184;, score=0.733 total time=   0.0s
# [CV 1/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 1/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.760 total time=   0.0s
# [CV 2/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 2/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.783 total time=   0.0s
# [CV 3/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 3/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.799 total time=   0.0s
# [CV 4/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 4/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.781 total time=   0.0s
# [CV 5/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 5/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.778 total time=   0.0s
# [CV 6/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 6/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.833 total time=   0.0s
# [CV 7/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 7/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.789 total time=   0.0s
# [CV 8/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 8/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.784 total time=   0.0s
# [CV 9/10; 50/53] START ccp_alpha=0.04443086862511203............................
# [CV 9/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.788 total time=   0.0s
# [CV 10/10; 50/53] START ccp_alpha=0.04443086862511203...........................
# [CV 10/10; 50/53] END ccp_alpha=0.04443086862511203;, score=0.733 total time=   0.0s
# [CV 1/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 1/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.760 total time=   0.0s
# [CV 2/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 2/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.660 total time=   0.0s
# [CV 3/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 3/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.694 total time=   0.0s
# [CV 4/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 4/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.630 total time=   0.0s
# [CV 5/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 5/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.653 total time=   0.0s
# [CV 6/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 6/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.716 total time=   0.0s
# [CV 7/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 7/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.695 total time=   0.0s
# [CV 8/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 8/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.784 total time=   0.0s
# [CV 9/10; 51/53] START ccp_alpha=0.07715268565273038............................
# [CV 9/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.678 total time=   0.0s
# [CV 10/10; 51/53] START ccp_alpha=0.07715268565273038...........................
# [CV 10/10; 51/53] END ccp_alpha=0.07715268565273038;, score=0.714 total time=   0.0s
# [CV 1/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 1/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.546 total time=   0.0s
# [CV 2/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 2/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.546 total time=   0.0s
# [CV 3/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 3/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.547 total time=   0.0s
# [CV 4/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 4/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.546 total time=   0.0s
# [CV 5/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 5/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.544 total time=   0.0s
# [CV 6/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 6/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.544 total time=   0.0s
# [CV 7/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 7/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.544 total time=   0.0s
# [CV 8/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 8/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.543 total time=   0.0s
# [CV 9/10; 52/53] START ccp_alpha=0.16695651453756688............................
# [CV 9/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.544 total time=   0.0s
# [CV 10/10; 52/53] START ccp_alpha=0.16695651453756688...........................
# [CV 10/10; 52/53] END ccp_alpha=0.16695651453756688;, score=0.544 total time=   0.0s
# [CV 1/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 1/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.379 total time=   0.0s
# [CV 2/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 2/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.379 total time=   0.0s
# [CV 3/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 3/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.380 total time=   0.0s
# [CV 4/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 4/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.380 total time=   0.0s
# [CV 5/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 5/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.378 total time=   0.0s
# [CV 6/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 6/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.378 total time=   0.0s
# [CV 7/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 7/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.378 total time=   0.0s
# [CV 8/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 8/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.377 total time=   0.0s
# [CV 9/10; 53/53] START ccp_alpha=0.1789914162845193.............................
# [CV 9/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.377 total time=   0.0s
# [CV 10/10; 53/53] START ccp_alpha=0.1789914162845193............................
# [CV 10/10; 53/53] END ccp_alpha=0.1789914162845193;, score=0.377 total time=   0.0s
# CPU times: total: 9.06 s
# Wall time: 9.05 s
# GridSearchCV(cv=10,
#              estimator=DecisionTreeClassifier(min_samples_leaf=20,
#                                               random_state=42),
#              param_grid={'ccp_alpha': array([0.00000000e+00, 1.58474100e-05, 1.81501093e-05, 2.06258275e-05,
#        3.19713788e-05, 8.96513805e-05, 1.21368157e-04, 1.52653283e-04,
#        1.59718241e-04, 2.70594797e-04, 2.71462504e-04, 2.85818694e-04,
#        3.40466842e-04, 3.41934337e-04, 6.08219967e-04, 6.085...
#        1.61344166e-03, 1.65242286e-03, 2.00725640e-03, 2.44801917e-03,
#        2.48885616e-03, 2.96921364e-03, 3.30473634e-03, 3.41518950e-03,
#        3.53930729e-03, 3.64557787e-03, 4.01299501e-03, 4.39460863e-03,
#        6.08432368e-03, 6.83698452e-03, 7.62086740e-03, 1.18778641e-02,
#        1.25648982e-02, 1.50665213e-02, 1.60819163e-02, 1.89866339e-02,
#        3.55252262e-02, 4.44308686e-02, 7.71526857e-02, 1.66956515e-01,
#        1.78991416e-01])},
#              verbose=100)

# %% [markdown]
# ### 4. Avaliando a árvore
#
# - Obtenha a árvore na melhor configuração treinada em toda a base de treino
# - Calcule a acurácia dessa árvore na base de testes
# - Visualize a matriz de confusão

# %%
grid.best_score_
# Out:
# 0.8167794291629695

# %%
melhor_ccp = DecisionTreeClassifier(random_state=2360873, ccp_alpha=0.8167792443064181).fit(top_train, y_train)

# %%
clf.score(top_test, y_test)
# Out:
# 0.7254835425856804

# %%
y_pred = melhor_ccp.predict(top_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[  0,   0,   0,   0,   0, 496],
#        [  0,   0,   0,   0,   0, 471],
#        [  0,   0,   0,   0,   0, 420],
#        [  0,   0,   0,   0,   0, 491],
#        [  0,   0,   0,   0,   0, 532],
#        [  0,   0,   0,   0,   0, 537]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.ylabel('Predito',fontsize=13)
plt.xlabel('Real',fontsize=13)
plt.title('Confusion Matrix',fontsize=17)
acuracia_teste = melhor_ccp.score(top_test, y_test)

print(f'Acurácia: {acuracia_teste*100:.2f}')
plt.show()
# Out:
# Acurácia: 18.22

# %% [markdown]
# ### 5. Melhorando a árvore
#
# A melhor forma de se melhorar um algoritmo é colocando nele novas variáveis que agreguem valor. Podemos usar a força-bruta e ir colocando variáveis aleatoriamente - ou colocar todas e deixar rodando por um bom tempo - ou utilizar uma lógica eficiente e fazer uma seleção de variáveis.
#
# - Observe que há classes mais fáceis e mais difíceis de se identificar
# - Crie uma variável binária para uma das classes de maior erro
# - Fala uma árvore de classificação bem simples para esta variável:
#     - utilize ```mean_samples_leaf=20```
#     - utilize ```max_depth=4```
#     - coloque todas as variáveis
# - Observe a importância das variáveis, e selecione as 3 com maior importância
# - Rode novamente o algoritmo acima com as 3 novas variáveis e avalie a acurácia

# %% [markdown]
# |Codigo | Atividade|
# |-------|---------|
# |1      |Andando|
# |2      |Subindo escadas|
# |3      |Descendo escadas|
# |4      |Sentado|
# |5      |Em pé|
# |6      |Deitado|

# %%
# Define o limiar entre 4 e 5 - atividade de interesse 5 = atividade em pé 

y_treino = y_train.replace({5:1, 1:0,2:0, 3:0,4:0, 6:0})

# Cria a variável binária

y_treino
# Out:
#       0
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 7347  0
# 7348  0
# 7349  0
# 7350  0
# 7351  0
#
# [7352 rows x 1 columns]

# %%
X_treino = X_train.copy()

# %%
arvore = DecisionTreeClassifier(random_state=6969, max_depth=4, min_samples_leaf=20).fit(X_treino, y_treino)
best_variavel = pd.DataFrame({'Variavel': arvore.feature_importances_}, 
                             index=X_treino.columns).sort_values(by='Variavel', ascending=False)
best_variavel.head(3)
# Out:
#                                  Variavel
# angle(Y,gravityMean)             0.328048
# fBodyAcc-skewness()-X            0.301851
# fBodyAccJerk-bandsEnergy()-1,16  0.130431

# %%
X_novoteste = X_test[['angle(Y,gravityMean)','fBodyAcc-skewness()-X','fBodyAccJerk-bandsEnergy()-1,16']]
X_novotreino = X_train[['angle(Y,gravityMean)','fBodyAcc-skewness()-X','fBodyAccJerk-bandsEnergy()-1,16']]

# %%
y_teste = y_test.replace({5:1, 1:0,2:0, 3:0,4:0, 6:0})

# %%
nova_arvore = DecisionTreeClassifier(random_state=2360873, ccp_alpha=0.8167792443064181).fit(X_novotreino, y_treino)
nova_acuracia = nova_arvore.score(X_novoteste, y_teste)

print(f'Acurácia: {nova_acuracia*100:.2f}')
# Out:
# Acurácia: 81.95
